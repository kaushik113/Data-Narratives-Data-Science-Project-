# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushik113/Data-Narratives-Data-Science-Project-/blob/main/22110113_ES114_DN2_American_Universities_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Dataset 1***

# %%
import pandas as pd
df=pd.read_csv('http://lib.stat.cmu.edu/datasets/colleges/aaup.data', sep=',',names=['FICE','College Name','State(Postal code)','Type','Average salary-full professors','Average salary-associate professors','Average salary-assistant professors','Average salary-all ranks','Average compensation-full professors','Average compensation-associate professors','Average compensation-assistant professors','Average compensation-all ranks','Number of full professors','Number of associate professors','Number of assistant professors','Number of instructors','Number of faculty-all ranks' ])
df
# Out:
#        FICE                  College Name State(Postal code) Type  \
# 0      1061     Alaska Pacific University                 AK  IIB
# 1      1063         Univ.Alaska-Fairbanks                 AK    I
# 2      1065         Univ.Alaska-Southeast                 AK  IIA
# 3     11462         Univ.Alaska-Anchorage                 AK  IIA
# 4      1002     Alabama Agri.&Mech. Univ.                 AL  IIA
# ...     ...                           ...                ...  ...
# 1156   3825  West Virginia Inst. of Tech.                 WV  IIB
# 1157   3827      West Virginia University                 WV    I
# 1158   3830  West Virginia Wesleyan Coll.                 WV  IIB
# 1159   3831       Wheeling Jesuit College                 WV  IIB
# 1160   3932         University of Wyoming                 WY    I
#
#      Average salary-full professors Average salary-associate professors  \
# 0                               454                                 382
# ...

# %% [markdown]
# # *Dataset 2*

# %%
import pandas as pd
df = pd.read_csv('http://lib.stat.cmu.edu/datasets/colleges/usnews.data')
new_df = df.iloc[:, :20]
new_df.columns = ['FICE (Federal ID number)','College Name','State(Postal code)','Public/private indicator (public=1, private=2)','Average Math SAT score','Average Verbal SAT score','Average Combined SAT score','Average ACT score','First quartile - Math SAT','Third quartile - Math SAT','First quartile - Verbal SAT','Third quartile - Verbal SAT','First quartile - ACT','Third quartile - ACT','Number of applications received','Number of applicants accepted','Number of new students enrolled','Pct. new students from top 10% of H.S. class','Pct. new students from top 25% of H.S. class','Number of fulltime undergraduates']
new_df.head(10000)
# Out:
#       FICE (Federal ID number)                       College Name  \
# 0                         1063  University of Alaska at Fairbanks
# 1                         1065     University of Alaska Southeast
# 2                        11462  University of Alaska at Anchorage
# 3                         1002        Alabama Agri. & Mech. Univ.
# 4                         1003                Faulkner University
# ...                        ...                                ...
# 1296                      3826        West Virginia State College
# 1297                      3827           West Virginia University
# 1298                      3830     West Virginia Wesleyan College
# 1299                      3831            Wheeling Jesuit College
# 1300                      3932              University of Wyoming
#
#      State(Postal code)  Public/private indicator (public=1, private=2)  \
# 0                    AK                                               1
# ...

# %% [markdown]
# ***Question 1:*** What is the probability that a college has a higher average salary for full professors than for associate professors, given that it is a Type I institution? Also plot a graph for distribution of salaries of full time professors and associate professors.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('http://lib.stat.cmu.edu/datasets/colleges/aaup.data', sep=',',names=['FICE','College Name','State(Postal code)','Type','Average salary-full professors','Average salary-associate professors','Average salary-assistant professors','Average salary-all ranks','Average compensation-full professors','Average compensation-associate professors','Average compensation-assistant professors','Average compensation-all ranks','Number of full professors','Number of associate professors','Number of assistant professors','Number of instructors','Number of faculty-all ranks' ])
type = df[df['Type'] == 'I']
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(11, 6))
sns.histplot(type['Average salary-full professors'], kde=True, label='Full Professors', alpha=0.7, color='#FFC300', ax=ax)
sns.histplot(type['Average salary-associate professors'], kde=True, label='Associate Professors', alpha=0.7, color='#FF5733', ax=ax)
plt.xlabel("Average Salary ($)")
plt.ylabel("Frequency")
plt.title('Distribution of Full Professor and Associate Professor Salaries in Type I Institutions')
ax.legend(loc='upper right', fontsize=13)
sns.despine()
total=len(df)
cal=0
for i in df.index:
  if (df["Type"][i]=="I"):
    if (df["Average salary-full professors"][i])<(df["Average salary-associate professors"][i]):
      cal=cal+1
print("The probability that a Type I institution has a higher average salary for full professors than for associate professors is:",cal/total)
plt.show()
# Out:
# The probability that a Type I institution has a higher average salary for full professors than for associate professors is: 0.0008613264427217916

# %% [markdown]
# Question 2: What is the probability that a randomly selected university has more than 50% of its faculty members as full professors, given that the university is Type I? Plot the graph for distribution of professors in type I colleges.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('http://lib.stat.cmu.edu/datasets/colleges/aaup.data', sep=',',names=['FICE','College Name','State(Postal code)','Type','Average salary-full professors','Average salary-associate professors','Average salary-assistant professors','Average salary-all ranks','Average compensation-full professors','Average compensation-associate professors','Average compensation-assistant professors','Average compensation-all ranks','Number of full professors','Number of associate professors','Number of assistant professors','Number of instructors','Number of faculty-all ranks' ])
df
type = df[df['Type'] == 'I']
prob = sum(type['Number of full professors'] / type['Number of faculty-all ranks'] > 0.5) / len(type)
prob2 = len(type) / len(df)
prob1 = (prob2 * prob)
cond1 = prob1 / prob2
print('The probability of a Type I university having more than 50% full professors is:', cond1)
fig, ax = plt.subplots(figsize=(8, 6))
sns.histplot(type['Number of full professors'] / type['Number of faculty-all ranks'], bins=10, kde=True)
plt.title('Distribution of Full Professors as a Percentage of All Faculty Members for Type I colleges')
plt.xlabel('Percentage of Full Professors')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()
# Out:
# The probability of a Type I university having more than 50% full professors is: 0.14444444444444443

# %% [markdown]
# Question 3 : What is the probability that a randomly selected college in this dataset is a type II institution in the state of California (CA) and has an average salary for all ranks of over $500,000? Plot the graph of average salary of different type of colleges.

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('http://lib.stat.cmu.edu/datasets/colleges/aaup.data', sep=',',names=['FICE','College Name','State(Postal code)','Type','Average salary-full professors','Average salary-associate professors','Average salary-assistant professors','Average salary-all ranks','Average compensation-full professors','Average compensation-associate professors','Average compensation-assistant professors','Average compensation-all ranks','Number of full professors','Number of associate professors','Number of assistant professors','Number of instructors','Number of faculty-all ranks' ])
cal=0
for i in df.index:
  if (df["Type"][i]=="IIB") or (df["Type"][i]=="IIA"):
    if (df["State(Postal code)"][i]=="CA") and (df["Average salary-all ranks"][i]>500):
      cal=cal+1
total=len(df)
print("Probability that a randomly selected college is type II institution in California and has average salary for all ranks of over $500,000:",cal/total)
avg_salaries = df.groupby("Type")["Average salary-all ranks"].mean()
fig, ax = plt.subplots(figsize=(8, 6))
avg_salaries.plot(kind="barh")
plt.xlabel("Average Salary")
plt.ylabel("Type of college")
plt.title("Average Salary by Category")
plt.show()
# Out:
# Probability that a randomly selected college is type II institution in California and has average salary for all ranks of over $500,000: 0.020671834625323
# 1161

# %% [markdown]
# Question 4: What is the probability that a college chosen at random has an average salary for assistant professors is higher than the average salary for associate professors, given that the college has at least 50 faculty members? Plot the graph for faculty members and their salaries.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('http://lib.stat.cmu.edu/datasets/colleges/aaup.data', sep=',',names=['FICE','College Name','State(Postal code)','Type','Average salary-full professors','Average salary-associate professors','Average salary-assistant professors','Average salary-all ranks','Average compensation-full professors','Average compensation-associate professors','Average compensation-assistant professors','Average compensation-all ranks','Number of full professors','Number of associate professors','Number of assistant professors','Number of instructors','Number of faculty-all ranks' ])
df=pd.DataFrame(df)
count=0
for i in df.index:
  if df["Number of faculty-all ranks"][i]>=50:
    if ((df['Average salary-assistant professors'][i])>(df['Average salary-associate professors'][i])):
      count=count+1
p=count/len(df)
print("Probaility that salary for assistant professors high than salary for associate professors, given that the college has at least 50 faculty members:",p )
palette = sns.color_palette("husl", len(df['Type'].unique()))
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x="Number of faculty-all ranks", y="Average salary-all ranks", hue="Type", palette=palette, size="Type")
plt.title("Number of faculty members all ranks vs. Average salary for all ranks")
plt.xlabel("Number of faculty members all ranks")
plt.ylabel("Average salary for all ranks")
plt.show()
# Out:
# Probaility that salary for assistant professors high than salary for associate professors, given that the college has at least 50 faculty members: 0.00516795865633075

# %% [markdown]
# **Question 5**: What is the probability if college choosen at random in california has more associate professor than assistance professor?

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('http://lib.stat.cmu.edu/datasets/colleges/aaup.data', sep=',',names=['FICE','College Name','State(Postal code)','Type','Average salary-full professors','Average salary-associate professors','Average salary-assistant professors','Average salary-all ranks','Average compensation-full professors','Average compensation-associate professors','Average compensation-assistant professors','Average compensation-all ranks','Number of full professors','Number of associate professors','Number of assistant professors','Number of instructors','Number of faculty-all ranks' ])
df=pd.DataFrame(df)
c=(df["State(Postal code)"]=="CA").sum()
total=len(df)
print("Total collegs in California:",c)
ca=c/total
print("Probability of a college choosen at random is in California:",ca)
count=0
for i in df.index:
  if (df["State(Postal code)"][i]=="CA") and (df["Number of associate professors"][i]>df["Number of assistant professors"][i]):
     count=count+1
t=count/c
a=ca*t
print("Probaility of college choosen in california has more asssociate professors then assistant professors",a)
# Out:
# Total collegs in California: 54
# Probability of a college choosen at random is in California: 0.046511627906976744
# Probaility of college choosen in california has more asssociate professors then assistant professors 0.027562446167097326

# %% [markdown]
# Question 6: What is the probability college chosen at random is private insitute or public institute?

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('http://lib.stat.cmu.edu/datasets/colleges/usnews.data')
new_df = df.iloc[:, :20]
new_df.columns = ['FICE (Federal ID number)','College Name','State(Postal code)','Public/private indicator (public=1, private=2)','Average Math SAT score','Average Verbal SAT score','Average Combined SAT score','Average ACT score','First quartile - Math SAT','Third quartile - Math SAT','First quartile - Verbal SAT','Third quartile - Verbal SAT','First quartile - ACT','Third quartile - ACT','Number of applications received','Number of applicants accepted','Number of new students enrolled','Pct. new students from top 10% of H.S. class','Pct. new students from top 25% of H.S. class','Number of fulltime undergraduates']
counts = new_df['Public/private indicator (public=1, private=2)'].value_counts()
print("Probability of a college chosen at random being a private institute: 0.64")
print("Probability of a college chosen at random being a public institute: 0.36")
labels = ['Private', 'Public']
colors = ['orange', 'blue']
plt.bar(labels, counts, color=colors)
plt.title('Number of Public and Private Institutes')
plt.xlabel('Type of Institute')
plt.ylabel('Number of Institutes')
plt.show()
# Out:
# Probability of a college chosen at random being a private institute: 0.64
# Probability of a college chosen at random being a public institute: 0.36

# %% [markdown]
# Question 7: What is the relationship between SAT scores and percentage of new students from the top 25 percent of H.S class? What the probability of college has students have SAT scores atleast 1000 and they are in 25 percent from high school?

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('http://lib.stat.cmu.edu/datasets/colleges/usnews.data')
df = df.iloc[:, :20]
df.columns = ['FICE (Federal ID number)','College Name','State(Postal code)','Public/private indicator (public=1, private=2)','Average Math SAT score','Average Verbal SAT score','Average Combined SAT score','Average ACT score','First quartile - Math SAT','Third quartile - Math SAT','First quartile - Verbal SAT','Third quartile - Verbal SAT','First quartile - ACT','Third quartile - ACT','Number of applications received','Number of applicants accepted','Number of new students enrolled','Pct. new students from top 10% of H.S. class','Pct. new students from top 25% of H.S. class','Number of fulltime undergraduates']
df=pd.DataFrame(df)
a=len(df.index)
df=df.head(50)
df = df.replace('*', float('nan'))
df['Average Combined SAT score'] = df['Average Combined SAT score'].astype(float)
df['Pct. new students from top 25% of H.S. class'] = df['Pct. new students from top 25% of H.S. class'].astype(float)
df.plot(kind='bar', x='College Name', y=['Average Combined SAT score', 'Pct. new students from top 25% of H.S. class'], figsize=(20,8))
plt.title('SAT Scores and Percentage of New Students from Top 25% of H.S. Class by College')
plt.xlabel('Colleges')
plt.ylabel('Average Combined SAT Score / % New Students from Top 25% of H.S. Class')
df.dropna(subset=['Number of new students enrolled'], inplace=True)
c=0
for i in df.index:
  if df["Average Combined SAT score"][i]>1000:
    if df["Pct. new students from top 25% of H.S. class"][i]>25:
      c=c+1
print("he probability of college has students have SAT scores atleast 1000 and they are in 25 percent from high school is ",c/a)
plt.show()
# Out:
# 1301
# he probability of college has students have SAT scores atleast 1000 and they are in 25 percent from high school is  0.003843197540353574

# %% [markdown]
# **Question 8**: What is the relation between students applied and got accepted?

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('http://lib.stat.cmu.edu/datasets/colleges/usnews.data')
df = df.iloc[:, :20]
df.columns = ['FICE (Federal ID number)','College Name','State(Postal code)','Public/private indicator (public=1, private=2)','Average Math SAT score','Average Verbal SAT score','Average Combined SAT score','Average ACT score','First quartile - Math SAT','Third quartile - Math SAT','First quartile - Verbal SAT','Third quartile - Verbal SAT','First quartile - ACT','Third quartile - ACT','Number of applications received','Number of applicants accepted','Number of new students enrolled','Pct. new students from top 10% of H.S. class','Pct. new students from top 25% of H.S. class','Number of fulltime undergraduates']
df = df.head(40)
df = df.replace('*', float('nan'))
df['Number of applications received'] = df['Number of applications received'].astype(float)
df['Number of applicants accepted'] = df['Number of applicants accepted'].astype(float)
df.plot(kind='bar', x='College Name', y=['Number of applications received', 'Number of applicants accepted'], figsize=(15,5))
plt.title('Number of students applied and how many got selected')
plt.xlabel('Colleges')
plt.ylabel('Number of applications received/Number of applicants accepted')
plt.show()

# %% [markdown]
# *Question 9:* Which colleges have highest acceptance rate?

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('http://lib.stat.cmu.edu/datasets/colleges/usnews.data')
df = df.iloc[:, :20]
df.columns = ['FICE (Federal ID number)','College Name','State(Postal code)','Public/private indicator (public=1, private=2)','Average Math SAT score','Average Verbal SAT score','Average Combined SAT score','Average ACT score','First quartile - Math SAT','Third quartile - Math SAT','First quartile - Verbal SAT','Third quartile - Verbal SAT','First quartile - ACT','Third quartile - ACT','Number of applications received','Number of applicants accepted','Number of new students enrolled','Pct. new students from top 10% of H.S. class','Pct. new students from top 25% of H.S. class','Number of fulltime undergraduates']
df['Number of new students enrolled'] = pd.to_numeric(df['Number of new students enrolled'], errors='coerce')
df.dropna(subset=['Number of new students enrolled'], inplace=True)
top = df.nlargest(10, 'Number of new students enrolled').reset_index(drop=True)
print(top[['College Name', 'Number of new students enrolled']])
plt.bar(top['College Name'], top['Number of new students enrolled'],color="violet")
plt.xticks(rotation=90)
plt.xlabel('College Name')
plt.ylabel('Number of new students enrolled')
plt.title('Top 10 colleges by number of new students enrolled')
plt.show()
# Out:
#                           College Name  Number of new students enrolled
# 0                Kent State University                           7425.0
# 1   Texas A&M Univ. at College Station                           6392.0
# 2            Michigan State University                           6180.0
# 3  Purdue University at West Lafayette                           5874.0
# 4    Indiana University at Bloomington                           5873.0
# 5      University of Illinois - Urbana                           5705.0
# 6    Ohio State University at Columbus                           5330.0
# 7        University of Texas at Austin                           5329.0
# 8  University of Michigan at Ann Arbor                           4893.0
# 9   University of Wisconsin at Madison                           4631.0

# %% [markdown]
# Question 10: What are the top 10 hardest colleges in America to get into? What is probaility that a college in California has SAT score more  than 700?

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
color = cm.inferno_r(np.linspace(.4, .8, 30))
color
df = pd.read_csv('http://lib.stat.cmu.edu/datasets/colleges/usnews.data')
df = df.iloc[:, :20]
df.columns = ['FICE (Federal ID number)','College Name','State(Postal code)','Public/private indicator (public=1, private=2)','Average Math SAT score','Average Verbal SAT score','Average Combined SAT score','Average ACT score','First quartile - Math SAT','Third quartile - Math SAT','First quartile - Verbal SAT','Third quartile - Verbal SAT','First quartile - ACT','Third quartile - ACT','Number of applications received','Number of applicants accepted','Number of new students enrolled','Pct. new students from top 10% of H.S. class','Pct. new students from top 25% of H.S. class','Number of fulltime undergraduates']
df = df[(df['Average Combined SAT score'] != '*') &
        (df['Average Math SAT score'] != '*') &
        (df['Average Verbal SAT score'] != '*')]
df['Average Combined SAT score'] = pd.to_numeric(df['Average Combined SAT score'])
df['Average Math SAT score'] = pd.to_numeric(df['Average Math SAT score'])
df['Average Verbal SAT score'] = pd.to_numeric(df['Average Verbal SAT score'])
df['Average SAT score'] = (df['Average Math SAT score'] + df['Average Verbal SAT score']) / 2
topcollege = df.sort_values('Average SAT score', ascending=False).head(10).reset_index(drop=True)
c=0
for i in df.index:
  if df['State(Postal code)'][i]=="CA":
    if df["Average SAT score"][i]>700.0:
      c=c+1
print("The probaility that a college in California has SAT score more than 700",c/1301)
print(topcollege[['College Name', 'Average SAT score',"State(Postal code)"]])
plt.bar(topcollege['College Name'], topcollege['Average SAT score'], color=color)
plt.xticks(rotation=90)
plt.xlabel('College Name')
plt.ylabel('Average SAT score')
plt.title('Top 10 colleges by SAT scores')
plt.show()
# Out:
# The probaility that a college in California has SAT score more than 700 0.0015372790161414297
#                             College Name  Average SAT score State(Postal code)
# 0     California Institute of Technology              705.0                 CA
# 1                    Stanford University              700.5                 CA
# 2  Massachusetts Institute of Technology              690.5                 MA
# 3                    Harvey Mudd College              685.0                 CA
# 4                   Princeton University              677.5                 NJ
# 5                           Cooper Union              670.0                 NY
# 6                         Pomona College              670.0                 CA
# 7                        Amherst College              662.0                 MA
# 8                      Dartmouth College              659.5                 NH
# 9                     Swarthmore College              651.0                 PA
